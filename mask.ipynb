# %%
from urllib3 import PoolManager, request
import json

# %%
url=r'https://quality.data.gov.tw/dq_download_json.php?nid=116285&md5_url=2150b333756e64325bdbc4a5fd45fad1'
http=PoolManager()
r=http.request('GET',url)
data=json.loads(r.data)
data
# Out:
# /Users/cnwang/.virtualenvs/ak/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# [{'醫事機構代碼': '0145080011',
#   '醫事機構名稱': '衛生福利部花蓮醫院豐濱原住民分院',
#   '醫事機構地址': '花蓮縣豐濱鄉豐濱村光豐路４１號',
#   '醫事機構電話': '(03)8358141',
#   '成人口罩剩餘數': '3544',
#   '兒童口罩剩餘數': '1197',
#   '來源資料時間': '2020/04/01 05:02:37'},
#  {'醫事機構代碼': '0291010010',
#   '醫事機構名稱': '連江縣立醫院',
#   '醫事機構地址': '連江縣南竿鄉復興村２１７號',
#   '醫事機構電話': '(083)623995',
#   '成人口罩剩餘數': '93',
#   '兒童口罩剩餘數': '20',
#   '來源資料時間': '2020/04/01 05:02:37'},
#  {'醫事機構代碼': '2101010013',
#   '醫事機構名稱': '松山健康服務中心',
#   '醫事機構地址': '臺北市松山區八德路４段６９２號６樓',
#   '醫事機構電話': '(02)27671757',
#   '成人口罩剩餘數': '10',
#   '兒童口罩剩餘數': '1075',
#   '來源資料時間': '2020/04/01 05:02:37'},
#  {'醫事機構代碼': '2101020019',
#   '醫事機構名稱': '大安健康服務中心',
# ...

# %%
pharmaciesUrl=r'https://raw.githubusercontent.com/kiang/pharmacies/master/json/points.json'
http=PoolManager()
r=http.request('GET',pharmaciesUrl)
pharmaciesData=json.loads(r.data)['features']
# Out:
# /Users/cnwang/.virtualenvs/ak/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
pharmaciesData[0]
# Out:
# {'type': 'Feature',
#  'properties': {'id': '5901012490',
#   'name': '中美藥局',
#   'phone': '02 -27627468',
#   'address': '台北市松山區富錦街531號',
#   'mask_adult': 0,
#   'mask_child': 0,
#   'updated': '2020/04/11 13:44:05',
#   'available': '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#   'note': '本局每日早上9:00，發放口罩號碼牌',
#   'custom_note': '',
#   'website': '',
#   'county': '臺北市',
#   'town': '松山區',
#   'cunli': '新益里',
#   'service_periods': 'NNNNNNNNNNNNNNNNNNNNN'},
#  'geometry': {'type': 'Point', 'coordinates': [121.565481, 25.061285]}}

# %%
def geoDistance(loc1,loc2):
    import math

    R = 6373.0
    #radius of the Earth

    lat1 = math.radians(loc1[1])
    #coordinates
    lon1 = math.radians(loc1[0])
    lat2 = math.radians(loc2[1])
    lon2 = math.radians(loc2[0])

    dlon = lon2 - lon1
    #change in coordinates
    dlat = lat2 - lat1

    a = math.sin(dlat / 2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon / 2)**2
    #Haversine formula
    c = 2 * math.atan2(math.sqrt(a), math.sqrt(1 - a))
    distance = R * c

    return distance

# %%
geoDistance([24,120],[24,121])
# Out:
# 101.61329553176012

# %%
import pandas as pd

# %%
df=pd.DataFrame(pharmaciesData)

# %%
df.iloc[0]['geometry']['coordinates']
# Out:
# [121.565481, 25.061285]

# %%
geoDistance([120.997865,24.776255],df.iloc[0]['geometry']['coordinates'])
# Out:
# [121.565481, 25.061285]
# 65.44942157284879

# %%
distance=[]
for i in range(0,len(df)):
    distance.append(geoDistance([120.997865,24.776255],df.iloc[i]['geometry']['coordinates']))

# %%
df['distance']=distance

# %%
k=df.loc[(df['distance']<3.5) & (df['properties']['mask_child'])>0 ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-65c50ed64ab4> in <module>
# ----> 1 k=df.loc[(df['distance']<3.5) & (df['properties']['mask_child'])>0 ]
#
# ~/.virtualenvs/ak/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/.virtualenvs/ak/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4372         try:
#    4373             return self._engine.get_value(s, k,
# -> 4374                                           tz=getattr(series.dtype, 'tz', None))
#    4375         except KeyError as e1:
#    4376             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
for kk in k:
    print (f".{kk['name']}. Child:{kk['mask_child']}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-2ed520a81b82> in <module>
#       1 for kk in k:
# ----> 2     print (f".{kk['name']}. Child:{kk['mask_child']}")
#
# TypeError: string indices must be integers

# %%
print(k.iloc[0]['properties']['mask_child'])
# Out:
# 19

# %%
df['child_mask']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/ak/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'child_mask'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-c7998a3e9d2b> in <module>
# ----> 1 df['child_mask']
#
# ...

# %%
df['properties'][0]
# Out:
# {'id': '5901012490',
#  'name': '中美藥局',
#  'phone': '02 -27627468',
#  'address': '台北市松山區富錦街531號',
#  'mask_adult': 0,
#  'mask_child': 0,
#  'updated': '2020/04/10 14:18:04',
#  'available': '星期一上午看診、星期二上午看診、星期三上午看診、星期四上午看診、星期五上午看診、星期六上午看診、星期日上午看診、星期一下午看診、星期二下午看診、星期三下午看診、星期四下午看診、星期五下午看診、星期六下午看診、星期日下午看診、星期一晚上看診、星期二晚上看診、星期三晚上看診、星期四晚上看診、星期五晚上看診、星期六晚上看診、星期日晚上看診',
#  'note': '本局每日早上9:00，發放口罩號碼牌',
#  'custom_note': '',
#  'website': '',
#  'county': '臺北市',
#  'town': '松山區',
#  'cunli': '新益里',
#  'service_periods': 'NNNNNNNNNNNNNNNNNNNNN'}

# %%
type(pharmaciesData)
# Out:
# list

# %%
df=pd.DataFrame(pharmaciesData)

# %%
df.columns
# Out:
# Index(['geometry', 'properties', 'type'], dtype='object')

# %%
df['geometry']['coordinates']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-f0ac39ccbdb3> in <module>
# ----> 1 df['geometry']['coordinates']
#
# ~/.virtualenvs/ak/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/.virtualenvs/ak/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4372         try:
#    4373             return self._engine.get_value(s, k,
# -> 4374                                           tz=getattr(series.dtype, 'tz', None))
#    4375         except KeyError as e1:
#    4376             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
gpsurl=r'https://mycurrentlocation.net/'
http2=PoolManager()
r=http2.request('GET',gpsurl)
# Out:
# /Users/cnwang/.virtualenvs/ak/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [raw]
# r

# %%
r.data
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n\n    \n\n\n\n<!-- GOOGLE AUTO ADS SCRIPT IS HERE -->\n<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\n  <script>\n       (adsbygoogle = window.adsbygoogle || []).push({\n            google_ad_client: "ca-pub-9565694164036485",\n            enable_page_level_ads: true\n       });\n  </script>\n\n  \n\r\n    <title>My Current Location - Detect and Show Your Location Now on Maps</title>\r\n    <meta name="description" content="My Current Location Web detects Your Location and show it on Maps. We detect Your Coordinate and Location Name. Accurate Since 2015-Now!">\r\n    <meta name="keyword" content="my location, my current location, my location now, my location by map, google map my location, what is my location">\r\n    \r\n 
# ...

# %%
ip_request = http2.request('GET','https://get.geojs.io/v1/ip.json')
my_ip = json.loads(ip_request.data)['ip']  # ip_request.json() => {ip: 'XXX.XXX.XX.X'}
print(my_ip)
geo_request_url = 'https://get.geojs.io/v1/ip/geo/' + my_ip + '.json'
geo_request = http2.request('GET',geo_request_url)
geo_data = json.loads(geo_request.data)
print(geo_data)
# Out:
# /Users/cnwang/.virtualenvs/ak/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 114.34.185.22
# {'organization_name': 'Data Communication Business Group', 'region': 'Hsinchu', 'accuracy': 50, 'asn': 3462, 'organization': 'AS3462 Data Communication Business Group', 'timezone': 'Asia/Taipei', 'longitude': '120.9706', 'country_code3': 'TWN', 'area_code': '0', 'ip': '114.34.185.22', 'city': 'Hsinchu', 'country': 'Taiwan', 'continent_code': 'AS', 'country_code': 'TW', 'latitude': '24.8065'}
# ...

# %%
data={'name':'aaa','address':'nnn'}

# %%
data
# Out:
# {'name': 'aaa', 'address': 'nnn'}

# %%
da=[data,data]

# %%
da
# Out:
# [{'name': 'aaa', 'address': 'nnn'}, {'name': 'aaa', 'address': 'nnn'}]

# %%
da[0]['name']
# Out:
# 'aaa'

# %%
import location
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-d7a73f2efc65> in <module>
# ----> 1 import location
#
# ModuleNotFoundError: No module named 'location'
